# %% [markdown]
# # 다나와 크롤링

# %%
# 크롤링 하기 전에 페이지 여는 방법!

import webbrowser
url = 'www.naver.com'
webbrowser.open(url)
# Out:
# True

# %%
import webbrowser
url = 'www.daum.net'
webbrowser.open(url)
# Out:
# True

# %%
# 검색어까지 붙일거임(파이썬 검색)
# 검색한다음 링크를 복사해서 검색어부분만 지우고 따오기
# 네이버
import webbrowser
naver_url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query='
search_word = '파이썬'
url = naver_url + search_word

webbrowser.open(url)
# Out:
# True

# %%
# 검색어까지 붙일거임(파이썬 검색)
# 검색한다음 링크를 복사해서 검색어부분만 지우고 따오기
# 다음
import webbrowser
daum_url = 'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q='
search_word = '파이썬'
url = daum_url + search_word

webbrowser.open(url)
# Out:
# True

# %%
# 검색어까지 붙일거임(파이썬 검색)
# 검색한다음 링크를 복사해서 검색어부분만 지우고 따오기
# 네이트
import webbrowser
nate_url = 'https://search.daum.net/nate?thr=sbma&w=tot&q='
search_word = '파이썬'
url = nate_url + search_word

webbrowser.open(url)
# Out:
# True

# %%
# 검색어까지 붙일거임(파이썬 검색)
# 검색한다음 링크를 복사해서 검색어부분만 지우고 따오기
# 구글
import webbrowser
google_url = 'https://www.google.com/#q='
search_word = '파이썬'
url = google_url + search_word

webbrowser.open(url)
# Out:
# True

# %% [markdown]
# # 여러 개의 웹 사이트에 접속

# %%
import webbrowser

urls = ['www.naver.com',
        'www.google.com',
        'www.daum.net',
        'www.nate.com']

for url in urls :
    webbrowser.open_new(url)

# %%
네이버 : 이천 쌀
구글 : 이천 도자기
다음 : 이천 복숭아
네이트 : 이천 반도체

# %%
import webbrowser

urls = ['https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=',
        'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=',
        'https://search.daum.net/nate?thr=sbma&w=tot&q=',
        'https://www.google.com/#q=']

#search_words = {'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=' : '이천 쌀',
#                'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=' : '이천 도자기',
#                'https://search.daum.net/nate?thr=sbma&w=tot&q=' : '이천 복숭아',
#                'https://www.google.com/#q=' : '이천 반도체'}
search_words = ["이천 쌀","이천 도자기","이천 복숭아","이천 반도체"]

for i in range(0, len(search_words)) :
    url = urls[i] + search_words[i]
#    print(url)
    webbrowser.open_new(url)

# %%
num = int(input('아이가 태어난 지 몇 개월입니까?'))

if 0<= num <=1 :
    print('결핵 예방접종 대상자입니다.')
if 0<= num <=2 :
    print('B형 간염 예방접종 대상자입니다.')
if 2<= num <=6 :
    print('파상풍 예방접종 대상자입니다.')
if 2<= num <=15 :
    print('폐렴구균 예방접종 대상자입니다.')
# Out:
# 아이가 태어난 지 몇 개월입니까?5
# 파상풍 예방접종 대상자입니다.
# 폐렴구균 예방접종 대상자입니다.

# %%
score = float(input('학점이 몇 점입니까?'))

if score == 4.5:
    print('신')
elif 4.2 <= score < 4.5:
    print('교수님의 사랑')
elif 3.5 <= score < 4.2:
    print('현 체제의 수호자')
elif 2.8 <= score < 3.5:
    print('일반인')
elif 2.3 <= score < 2.8:
    print('일탈을 꿈꾸는 소시민')
elif 1.75 <= score < 2.3:
    print('오락문화의 선구자')
elif 1.0 <= score < 1.75:
    print('불가촉천민')
elif 0.5 <= score < 1.0:
    print('자벌레')
elif 0 < score < 0.5:
    print('플랑크톤')
elif score == 0:
    print('시대를 앞서가는 혁명의 씨앗')
else:
    print('다시 입력해주세요.')
# Out:
# 학점이 몇 점입니까?0.1
# 플랑크톤

# %%
passwd = input('패스워드를 입력하세요 : ')
p1 = int(passwd[0])
p2 = int(passwd[1])
p3 = int(passwd[2])
p4 = int(passwd[3])

#조건 1. 중복 확인
if (p1==p2 or p1==p3 or p1==p4) :
    print("암호 중복으로 다시 입력해주세요 : ")
elif (p2==p3 or p2==p4) :
    print("암호 중복으로 다시 입력해주세요 : ")
elif (p3==p4) :
    print("암호 중복으로 다시 입력해주세요 : ")
#조건 2. 연속 증가 확인
elif(p1+1==p2 or p2+1==p3 or p3+1==p4) : 
    print("연속되는 숫자는 안 돼요!")

#조건 3. 연속 감소 확인
elif(p1-1==p2 or p2-1==p3 or p3-1==p4):
    print("연속되는 숫자는 안 돼요!")

else:
    print("사용할 수 있는 암호입니다.")
# Out:
# 패스워드를 입력하세요 : 7236
# 연속되는 숫자는 안 돼요!

# %% [markdown]
# ### 다나와 검색 사이트에 접속

# %%
from selenium import webdriver

driver = webdriver.Chrome('chromedriver.exe')

url = 'http://search.danawa.com/dsearch.php?k1=usb&module=goods&act=dispMain'

driver.get(url)

# %%
# 웹페이지의 HTML 정보 가져오기

from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <html class="js no-touch" lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>usb 쇼핑검색 종합정보 :: 행복쇼핑의 시작 ! 다나와 (가격비교) - Danawa.com</title>
# <!-- <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/> -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="usb 쇼핑검색 종합정보 :: 행복쇼핑의 시작 ! 다나와 (가격비교) - Danawa.com" name="Title"/>
# <meta content="usb 최저가 상품 가격비교와 함께 사용기, 뉴스, 리뷰, 구매가이드, 중고시세 등의 쇼핑 추천정보를 풍부하게 제공합니다." name="Description"/>
# <meta content="usb, USB허브, USB메모리 4GB, USB메모리 8GB, USB메모리 2GB, 상품 추천, 구매, 구입, 쇼핑 검색, 가격 비교, 중고, 좋은, 뉴스, 사용기, 리뷰, 블로그, 최저가" name="Keywords"/>
# <meta content="nofollow" name="robots"/>
# <meta content="쇼핑검색 종합정보" property="og:title"/>
# <meta content="http://img.danawa.com/new/tour/img/logo/sns_danawa.jpg" property="og:image"/>
# <meta content="usb" property="og:description"/>
# <meta content="width=1280" name="viewport"/>
# ...

# %%
# usb 정보 가져오기

prod_items = soup.select('li.prod_item')
len(prod_items)
# Out:
# 41

# %%
# usb 제품명 가져오기

title = prod_items[0].select('p.prod_name > a')[0].text.strip()
print(title)
# Out:
# EFM ipTIME BT50

# %%
# usb 스펙 가져오기

specs = spec_list[0].select('p.spec_list > a')[0].text.strip()
print(specs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-c6b2dbca954b> in <module>
#       1 # usb 스펙 가져오기
#       2
# ----> 3 specs = spec_list[0].select('p.spec_list > a')[0].text.strip()
#       4 print(specs)
#
# NameError: name 'spec_list' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# li 위에 ul 위에 div가 있음
# li 밑에는 p 밑에는 a있음

# %%
# usb 정보 가져오기

prod_items = soup.select('li.prod_item')
len(prod_items)
# Out:
# 41

# %%
# usb 정보 가져오기

prod_items = soup.select('ul.product_list > li.prod_item')
len(prod_items)
# Out:
# 41

# %%
# usb 정보 가져오기

prod_items = soup.select('div,main_prodlist > ul.product_list > li.prod_item')
len(prod_items)
# Out:
# 1026

# %% [markdown]
# 3개가 다 다름! 나는 특수한 경우인듯

# %%
# 무선청소기 스펙목록 가져오기
spec_list = prod_items[0].select('div.spec_list')[0].text.strip()

print(spec_list)
# Out:
# USB 동글 / 단자 형태: Type A / 초소형 USB / 5.0 / 1년 / Realtek RTL8761B 칩셋 탑재 / 최대 20m 거리 지원 / 전송 속도: 3Mbps / 색상: 블랙, 화이트

# %%
# 무선청소기 스펙목록 가져오기 #콤마를 지워버리는거임 뒤쪽은
price = prod_items[0].select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(',', "")
print(price)
# Out:
# 4900

# %% [markdown]
# #### 반복문을 이용하여 1페이지 정보 가져오기

# %%
prod_data = []
for prod_item in prod_items :
#제품명 가져오기
    #상품명이 있을 경우
    try :
        title = prod_item.select('p.prod_name > a')[0].text.strip()
    #상품명이 없을 경우
    except :
        title = ''
        
    #상품 상세 정보 가져오기(Spec)
    try :
        spec_list = prod_item.select('div.spec_list')[0].text.strip()
    except:
        spec_list = ''
    
    #가격 가져오기
    try :
        price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(',', "")
    except:
        price = 0
        
    prod_data.append([title,spec_list,price])
    
print("전체 정보 : ", len(prod_data))
print()
print(prod_data)
# Out:
# 전체 정보 :  41
#
# ...

# %%
# 정보 추출을 위한 함수 만들기

def get_prod_items(prod_items) :

    prod_data = []

    for prod_item in prod_items :
    #제품명 가져오기
        #상품명이 있을 경우
        try :
            title = prod_item.select('p.prod_name > a')[0].text.strip()
        #상품명이 없을 경우
        except :
            title = ''

        #상품 상세 정보 가져오기(Spec)
        try :
            spec_list = prod_item.select('div.spec_list')[0].text.strip()
        except:
            spec_list = ''

        #가격 가져오기
        try :
            price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(',', "")
        except:
            price = 0

        prod_data.append([title,spec_list,price])
    
    return prod_data


print("전체 정보 : ", len(prod_data))
print()
print(prod_data)
# Out:
# 전체 정보 :  41
#
# ...

# %% [markdown]
# from get_prod_items import get_prod_items
# 이거 하면 계속 쓸 수 있음!

# %%
# 함수 테스트

prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
prod_data = get_prod_items(prod_items)
print(prod_data)
# Out:
# [['EFM ipTIME BT50', 'USB 동글 / 단자 형태: Type A / 초소형 USB / 5.0 / 1년 / Realtek RTL8761B 칩셋 탑재 / 최대 20m 거리 지원 / 전송 속도: 3Mbps / 색상: 블랙, 화이트', '4900'], ['Alkvh12APg', 'Alkvh12APg985452', '985452'], ['Sandisk Cruzer Blade Z50', 'USB 메모리 / USB 2.0 / 단자 형태: Type A / 보안기능 / 단자노출형 / 5년 이상 / AES 128 암호화', '1510'], ['Sandisk Ultra Flair CZ73', 'USB 메모리 / USB 3.0 / 단자 형태: Type A / 단자노출형 / 5년', '3500'], ['Sandisk Ultra Luxe CZ74', 'USB 메모리 / USB 3.0 / 단자 형태: Type A / 보안기능 / 단자노출형 / 5년 / 파일복구 SW 지원', '16600'], ['Sandisk Ultra Dual Drive Go Type C', 'USB 메모리 / USB 3.0 / 단자 형태: Type A, Type C / OTG 기능 / 스윙 / 5년 / 전용 어플리케이션 제공', '28780'], ['실리콘파워 Jewel J05', 'USB 메모리 / USB 3.0 / 단자 형태: Type A / 보안기능 / 방수기능 / 뚜껑형 / 5년 / 전용 소프트웨어 제공', '7890'], ['실리콘파워 MOBILE X31', 'USB 메모리 / USB 3.0 / 단자 형태: Type A, Micro B (5핀) / OTG 기능 / 보안기능 / 방수기능 / 스윙 / 5년 / 전용 소프트웨어 제공', '8460'], ['실리콘파워 Mobile C31 Dual Type C', 'USB 메모리 / USB 3.0 / 단자 형태: Type A, Type C / OTG 기능 / 방수기능 / 스윙 / 5년 / 전용 소프트웨어, 파일 탐색기 앱 제공 / 원터치 백업, 파
# ...

# %% [markdown]
# ### 다나와 검색 URL을 만들어주는 함수 생성

# %%
# 최소 몇 페이지를 가져오겠다!
def get_search_page_url(keyword, page) :
    # 쿼리랑 page에 {} 넣고 마지막 goods로 바꿔줌
    return "http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods".format(keyword, page)

keyword = '무선청소기'
page = 1
url = get_search_page_url(keyword, page)
print(url)
# Out:
# http://search.danawa.com/dsearch.php?query=무선청소기&volumeType=allvs&page=1&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods

# %% [markdown]
# python 스크립트파일명 키워드 검색페이지수
# cmd에다가 이렇게만 쓰면 끝나는거임

# %%
import time
from tqdm.notebook import tqdm

total_page = 10

for page in tqdm(range(1, total_page+1)) :
    time.sleep(5)

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
#import sys

# 최소 몇 페이지를 가져오겠다!
def get_search_page_url(keyword, page) :
    # 쿼리랑 page에 {} 넣고 마지막 goods로 바꿔줌
    return "http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods".format(keyword, page)

keyword = '무선청소기'
page = 1
url = get_search_page_url(keyword, page)

driver = webdriver.Chrome('chromedriver.exe')
driver.implicitly_wait(3)

#input_keyword = sys.argv[1]
#input_page = sys.argv[2]

keyword = '무선청소기' #input_keyword
total_page = 10 #input_page
prod_data_total = []

for page in tqdm(range(1, total_page+1)) :
    
    #검색 페이지로 이동
    driver.get(url)
    url = get_search_page_url(keyword, page)
    time.sleep(5)
    
    #현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    #상품정보 추출
    prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
    prod_item_list = get_prod_items(prod_items)
    
    #추출된 데이터 저장
    prod_data_total = prod_data_total + prod_item_list
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da43b86af3a3> in <module>
#      18
#      19     #검색 페이지로 이동
# ---> 20     driver.get(url)
#      21     url = get_search_page_url(keyword, page)
#      22     time.sleep(5)
#
# NameError: name 'url' is not defined

# %%
prod_data_total
# Out:
# [['다이슨 V10 카본파이버',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 싸이클론 / 흡입력: 160AW / 충전시간: 3시간30분 / 사용시간: 1시간 / 배터리: 리튬이온 / 구성: 소프트롤러, 토크드라이브, 미니모터, 솔형, 더스팅, 틈새, 긴틈새, 연장툴, 도킹스테이션 / 무게: 2.5kg / 소비전력: 525W / 크기(가로x세로x깊이): 250x1241x256mm',
#   '510720'],
#  ['삼성전자 제트 VS15R8500BF',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 150W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 40분 / 배터리: 리튬이온 / 구성: 바닥, 솔형, 틈새, 거치대 / 디스플레이표시창 / 프리볼트 / 무게: 2.57kg / 색상:틸민트 / 소비전력: 410W / 알레르기인증(BAF) / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1123x215mm',
#   '391500'],
#  ['pWa1IYOxJy', 'pWa1IYOxJy680484', '680484'],
#  ['LG전자 코드제로 A9S A9700',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 구성: 바닥, 물걸레, 침구, 솔형, 굳은먼지, 상부청소, 틈새, 긴틈새, 매트리스, 연장툴, 거치대 / 자동물공급 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:판타지실버 / 소비전력: 590W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1120x260mm',
#   '963200'],
#  ['샤오미 드리미 V10',
# ...

# %%
# 엑셀 파일로 저장
import pandas as pd
data = pd.DataFrame(prod_data_total)
data.columns = ['상품명', '상품정보', '가격']
data.to_excel('danawa_results.xlsx', index=False)

# %% [markdown]
# ### 통합본

# %%
#%%writefile D:\python\danawa.py
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
import pandas as pd
import sys

driver = webdriver.Chrome('chromedriver.exe')
driver.implicitly_wait(3)

input_keyword = sys.argv[1]
input_page = sys.argv[2]

keyword =  input('input_keyword : ')
total_page = int(input('input_page : '))
prod_data_total = []

def get_search_page_url(keyword, page) :
    # 쿼리랑 page에 {} 넣고 마지막 goods로 바꿔줌
    return "http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods".format(keyword, page)

def get_prod_items(prod_items) :

    prod_data = []

    for prod_item in prod_items :
    #제품명 가져오기
        #상품명이 있을 경우
        try :
            title = prod_item.select('p.prod_name > a')[0].text.strip()
        #상품명이 없을 경우
        except :
            title = ''

        #상품 상세 정보 가져오기(Spec)
        try :
            spec_list = prod_item.select('div.spec_list')[0].text.strip()
        except:
            spec_list = ''

        #가격 가져오기
        try :
            price = prod_item.select('li.rank_one > p.price_sect > a > strong')[0].text.strip().replace(',', "")
        except:
            price = 0

        prod_data.append([title,spec_list,price])
    
    return prod_data

for page in tqdm(range(1, total_page+1)) :
    
    #검색 페이지로 이동
    driver.get(url)
    url = get_search_page_url(keyword, page)
    time.sleep(5)
    
    #현재 페이지의 HTML 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    #상품정보 추출
    prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
    prod_item_list = get_prod_items(prod_items)
    
    #추출된 데이터 저장
    prod_data_total = prod_data_total + prod_item_list
    
# 엑셀 파일로 저장
data = pd.DataFrame(prod_data_total)
data.columns = ['상품명', '상품정보', '가격']
data.to_excel('danawa_results.xlsx', index=False)
# Out:
# input_keyword : usb
# input_page : 1
# ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\users\kitri\appdata\local\programs\python\python38\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# c:\users\kitri\appdata\local\programs\python\python38\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# c:\users\kitri\appdata\local\programs\python\python38\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     634         try:
# --> 635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     636                                 allowZip64=self.allow_zip64)
#
# ...

# %%
import warnings
#경고메시지 숨기기
warnings.filterwarnings(action='ignore')

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import tqdm
import warnings

# 경고메시지 숨기기
# warnings.filterwarnings(action='ignore')를 action='default'로 변경하면 경고메시지가 나타난다.
warnings.filterwarnings(action='ignore')



def get_search_page_url(keyword, page):
    return 'http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=30&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods&tab=goods'.format(keyword, page)

keyword = input("검색어를 입력해주세요 : ")
pages = int(input("검색할 페이지숫자를 입력해주세요 : "))

page = 1
url = get_search_page_url(keyword, page)
print(url)



def get_prod_items(prod_items):
    prod_data = []
    for prod_item in prod_items:
        try: 
            title = prod_item.select('p.prod_name > a')[0].text.strip()
        except:
            title = ''
        try: 
            spec_list = prod_item.select('div.spec_list')[0].text.strip()
        except:
            spec_list = ''
        try: 
            price = int(prod_item.select('p.price_sect > a > strong')[0].text.strip().replace(",",""))
        except:
            price = 0
        prod_data.append([title, spec_list, price])
    return prod_data



# 윈도우에서는 .exe 추가해주세요
driver = webdriver.Chrome('chromedriver') 
driver.implicitly_wait(3)

total_page = pages
prod_data_total = []



print("처리중")
for page in tqdm(range(1,total_page+1)):
    driver.get(url)
    url = get_search_page_url(keyword, page)
    time.sleep(2)
    
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    
    prod_items = soup.select('div.main_prodlist > ul.product_list > li.prod_item')
    prod_item_list = get_prod_items(prod_items)
    
    prod_data_total = prod_data_total + prod_item_list


data = pd.DataFrame(prod_data_total)
data.columns = ['상품명', '스펙 목록', '가격']
data = data.sort_values(['가격'], ascending=[True])
data.to_excel('danawa_{}_crawling_result.xlsx'.format(keyword), index=False)
driver.close()
print('완료')
# Out:
# 검색어를 입력해주세요 : usb
# 검색할 페이지숫자를 입력해주세요 : 10
# http://search.danawa.com/dsearch.php?query=usb&volumeType=allvs&page=1&limit=30&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods&tab=goods
# 처리중
# ...
# 완료
